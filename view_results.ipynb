# %%
from visualize import *
from os import listdir

# %%
f, axes = plt.subplots(ncols=5, nrows=3)

# %%
directory = 'experiment_results'

# %% [markdown]
# # L20 - Momentum

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l20' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.1' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l20' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.01' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l20' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,100))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l20' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.0001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # L20 - SGD

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l20' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.1' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l20' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.01' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l20' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,100))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l20' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.0001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # L20 - Adam

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l20' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.1' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l20' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.01' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l20' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,100))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l20' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.0001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # L3 - Momentum

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l3' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.1' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 23 results
#   r = func(a, **kwargs)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l3' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.01' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l3' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,100))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l3' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.0001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests
# Out:
# ['experiment_results/l20_h100_bs128_lr0.0001_g0.0_w1_m0.9_t14.csv',
#  'experiment_results/l20_h100_bs128_lr0.0001_g0.1_w1_m0.9_t11.csv',
#  'experiment_results/l20_h100_bs128_lr0.0001_g0.5_w1_m0.9_t10.csv',
#  'experiment_results/l20_h100_bs128_lr0.0001_g1.0_w1_m0.9_t11.csv',
#  'experiment_results/l20_h100_bs128_lr0.0001_g3.0_w1_m0.9_t10.csv']

# %% [markdown]
# # L3 - SGD

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l3' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.1' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l3' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.01' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l3' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,100))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l3' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.0001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # L3 - Adam

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l3' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.1' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l3' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.01' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l3' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,100))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l3' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.0001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # L1x1024 - Momentum

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l1' in file
             and 'h1024' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.1' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 33 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 37 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 38 results
#   r = func(a, **kwargs)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l1' in file
             and 'h1024' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.01' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 72 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 71 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 73 results
#   r = func(a, **kwargs)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l1' in file
             and 'h1024' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,100))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 97 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 98 results
#   r = func(a, **kwargs)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l1' in file
             and 'h1024' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.0001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 496 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 497 results
#   r = func(a, **kwargs)

# %%
interests
# Out:
# ['experiment_results/l1_h1024_bs128_lr0.0001_g0.0_w1_m0.9_t1.csv',
#  'experiment_results/l1_h1024_bs128_lr0.0001_g0.1_w1_m0.9_t1.csv',
#  'experiment_results/l1_h1024_bs128_lr0.0001_g0.5_w1_m0.9_t1.csv',
#  'experiment_results/l1_h1024_bs128_lr0.0001_g1.0_w1_m0.9_t1.csv',
#  'experiment_results/l1_h1024_bs128_lr0.0001_g3.0_w1_m0.9_t1.csv',
#  'experiment_results/l1_h1024_bs128_lr0.0001_g9.0_w1_m0.9_t1.csv']

# %% [markdown]
# # L1x1024 - SGD

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l1' in file
             and 'h1024' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.1' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 33 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 32 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 31 results
#   r = func(a, **kwargs)
# ...

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l1' in file
             and 'h1024' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.01' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 72 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 73 results
#   r = func(a, **kwargs)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l1' in file
             and 'h1024' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,100))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 97 results
#   r = func(a, **kwargs)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l1' in file
             and 'h1024' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.0001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 496 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 497 results
#   r = func(a, **kwargs)

# %% [markdown]
# # L1x1024 - Adam

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l1' in file
             and 'h1024' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.1' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l1' in file
             and 'h1024' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.01' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l1' in file
             and 'h1024' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,100))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l1' in file
             and 'h1024' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.0001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # L2x64 - Momentum

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l2' in file
             and 'h64' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.1' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 19 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 15 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 9 results
#   r = func(a, **kwargs)
# ...

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l2' in file
             and 'h64' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.01' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 69 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 71 results
#   r = func(a, **kwargs)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l2' in file
             and 'h64' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,100))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l2' in file
             and 'h64' in file
             and 'w1' in file
             and 'm0.9' in file
             and 'lr0.0001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 495 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 496 results
#   r = func(a, **kwargs)

# %%
interests
# Out:
# ['experiment_results/l2_h64_bs128_lr0.0001_g0.0_w1_m0.9_t1.csv',
#  'experiment_results/l2_h64_bs128_lr0.0001_g0.1_w1_m0.9_t1.csv',
#  'experiment_results/l2_h64_bs128_lr0.0001_g0.5_w1_m0.9_t1.csv',
#  'experiment_results/l2_h64_bs128_lr0.0001_g1.0_w1_m0.9_t1.csv',
#  'experiment_results/l2_h64_bs128_lr0.0001_g3.0_w1_m0.9_t1.csv',
#  'experiment_results/l2_h64_bs128_lr0.0001_g9.0_w1_m0.9_t1.csv']

# %% [markdown]
# # L2x64 - SGD

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l2' in file
             and 'h64' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.1' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 37 results
#   r = func(a, **kwargs)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 36 results
#   r = func(a, **kwargs)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l2' in file
             and 'h64' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.01' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l2' in file
             and 'h64' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,100))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l2' in file
             and 'h64' in file
             and 'w1' in file
             and 'sgd' in file
             and 'lr0.0001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/numpy/lib/function_base.py:4011: RuntimeWarning: Invalid value encountered in median for 496 results
#   r = func(a, **kwargs)

# %% [markdown]
# # L2x64 - Adam

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l2' in file
             and 'h64' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.1' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l2' in file
             and 'h64' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.01' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,30))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l2' in file
             and 'h64' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,100))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
interests = [directory+'/'+file for file in listdir('./{}'.format(directory)) if
             True
             and 'l2' in file
             and 'h64' in file
             and 'w1' in file
             and 'adam' in file
             and 'lr0.0001' in file
             #and 'g9.0' not in file
             and 'g0.01' not in file
            ]
interests.sort()

dfs = load_dfs(interests)
plot(dfs,ylim=(0,400),xlim=(0,None))
# Out:
# /home/yaser/miniconda3/envs/dantemp/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)
